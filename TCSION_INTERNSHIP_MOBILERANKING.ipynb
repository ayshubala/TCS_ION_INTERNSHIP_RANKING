# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
train=pd.read_csv("MobileTrain.csv")
train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
test=pd.read_csv("MobileTest.csv")
test
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
# Columns:
# id-Unique values
# battery_power-Total energy a battery can store in one time measured in mAh
# blue-Bluetooth
# clock_speed-speed at which microprocessor executes instructions
# duel_sim
# fc-Front Camera mega pixels
# four_g
# int_memory-in GB
# m_dep-Mobile depth in cm
# mobile_wt- weight
# n_cores- no of cores of processor
# pc- primary cam pixel
# px_height-px resolution hight
# px_width- px width
# ram- ram in mb
# sc_h-screen hgt in cm
# sc_w- screen width in cm
# talk_time -longest time that a single battery charge will last when you are
# three_g- 3g
# touch_screen
# wifi

# %%
train.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# ...

# %%
train.dtypes.value_counts()
# Out:
# int64      19
# float64     2
# dtype: int64

# %%
train.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
train.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
train.shape
# Out:
# (2000, 21)

# %%
train["clock_speed"].value_counts()
# Out:
# 0.5    413
# 2.8     85
# 2.3     78
# 2.1     76
# 1.6     76
# 2.5     74
# 0.6     74
# 1.4     70
# 1.3     68
# 1.5     67
# 2.0     67
# 1.9     65
# 0.7     64
# 2.9     62
# 1.8     62
# 1.0     61
# 1.7     60
# 2.2     59
# 0.9     58
# 2.4     58
# 0.8     58
# 1.2     56
# 2.6     55
# 2.7     55
# 1.1     51
# 3.0     28
# Name: clock_speed, dtype: int64

# %%
train["m_dep"].value_counts()
# Out:
# 0.1    320
# 0.2    213
# 0.8    208
# 0.5    205
# 0.7    200
# 0.3    199
# 0.9    195
# 0.6    186
# 0.4    168
# 1.0    106
# Name: m_dep, dtype: int64

# %%
train_clone=train.copy()
train_clone
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
train.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
train.duplicated().sum()
# Out:
# 0

# %%
train.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %% [markdown]
# DATA ANALYSIS

# %%
discrete=[i for i in train.columns if train[i].nunique()<30]
discrete
# Out:
# ['blue',
#  'clock_speed',
#  'dual_sim',
#  'fc',
#  'four_g',
#  'm_dep',
#  'n_cores',
#  'pc',
#  'sc_h',
#  'sc_w',
#  'talk_time',
#  'three_g',
#  'touch_screen',
#  'wifi',
#  'price_range']

# %%
continuous=[i for i in train.columns if i not in discrete]
continuous
# Out:
# ['battery_power', 'int_memory', 'mobile_wt', 'px_height', 'px_width', 'ram']

# %%
for i in discrete:
  plt.title(i)
  sns.countplot(x=i,data=train)
  plt.show()

# %% [markdown]
# Inferences
#
#
# 1.   The number of SmartPhone having clock speed 0.05 is higher than others
# 2.   Most of the smartphones don't have front camera
# 3.   Smartphones having depth 0.1 is comparitly higher than the others.
# 4.   smartphones having primary camera 5mp is comparitivly less than others.
# 5.   Number of smartphones having screen width is gradually decreasing from 0
#      to 18
# 6.   Smartphones having 3G is greater than smartphones don't have 3G.

# %%
for i in continuous:
  plt.title(i)
  sns.distplot(train[i])
  plt.show()

# %% [markdown]
# Inference: Distribution of Pixel resolution height is skewed along the left side of the graph means mode<median<mode

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
for i in discrete:
  if i !="price_range":
    plt.title(i)
    sns.countplot(train,x=i,hue='price_range')
    plt.show()

# %% [markdown]
# Infernces
#
#
# 1.   The ratio of smartphones in price range "1" is lesser in smartphone having
#      depth 0.1cm and its higher in smartphone having depth 1 cm
# 2.   The ratio of smartphones in price range "3",ie, higher end smartphones is
#      higher in smartphone having screen height 17 cm while compared to others.
# 3.   The ratio of lower end smartphones is higher in smartphone having talktime 4hrs while compared to others.

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
cor=train.corr()
plt.figure(figsize=(20,20))
sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# Inferences
#
#
# 1.   RAM and Price range of the smartphone are highly positivly correlated with each other.
# 2.Pixel of Front camera and Primary camera are positivly correlated with each other.
# 3.Pixel resolution width and pixel resolution height are positivly correlated with eachother.
# 4.Screen width and Screen height are also shows positive correlation.
# 5.Also battery power and Price range shows some positive correlation.

# %% [markdown]
# OUTLIERS

# %%
for i in train.columns:
    plt.figure()
    plt.boxplot(train[i])
    plt.title(i)

# %% [markdown]
# Inference: The columns Pixel resolution height have Outliers

# %% [markdown]
# RANKING

# %% [markdown]
# The Dataframe.rank() function of Pandas is used to rank the data in different ways. After sorting (by default in ascending order), the position is used to determine the rank that is returned. If data contains equal values, then they are assigned with the average of the ranks of each value by default

# %%
df=train.copy()
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#Rank by price range
df["rank(price)"]=df["price_range"].rank(method="average").sort_values()
df.sort_values(by=["rank(price)"])
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1838            720     1          0.9         1  12       1          14
# 1762            808     1          0.5         1   3       0          46
# 419             914     1          0.9         0   2       0           4
# 846            1489     0          2.4         1   8       0          32
# 845            1907     0          2.0         0  13       0          55
# ...             ...   ...          ...       ...  ..     ...         ...
# 981            1046     1          2.8         1   0       1          58
# 982            1035     0          0.6         1   2       1          44
# 987            1688     0          2.5         0   0       1          21
# 956             862     0          2.3         0   9       1           6
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.iloc[1998,:]
# Out:
# battery_power    1512.0
# blue                0.0
# clock_speed         0.9
# dual_sim            0.0
# fc                  4.0
# four_g              1.0
# int_memory         46.0
# m_dep               0.1
# mobile_wt         145.0
# n_cores             5.0
# pc                  5.0
# px_height         336.0
# px_width          670.0
# ram               869.0
# sc_h               18.0
# sc_w               10.0
# talk_time          19.0
# three_g             1.0
# touch_screen        1.0
# wifi                1.0
# price_range         0.0
# rank(price)       250.5
# Name: 1998, dtype: float64

# %%
df["rank(price)"].value_counts()
# Out:
# 750.5     500
# 1250.5    500
# 1750.5    500
# 250.5     500
# Name: rank(price), dtype: int64

# %% [markdown]
# Ranking by other columns

# %%
for i in df.columns:
  if i not in ["price_range","rank(price)"]:
    title="rank("+i+")"
    df[title]=df[i].rank(method="average").sort_values()

df.sort_values(by=["rank(price)"])
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1838            720     1          0.9         1  12       1          14
# 1762            808     1          0.5         1   3       0          46
# 419             914     1          0.9         0   2       0           4
# 846            1489     0          2.4         1   8       0          32
# 845            1907     0          2.0         0  13       0          55
# ...             ...   ...          ...       ...  ..     ...         ...
# 981            1046     1          2.8         1   0       1          58
# 982            1035     0          0.6         1   2       1          44
# 987            1688     0          2.5         0   0       1          21
# 956             862     0          2.3         0   9       1           6
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# DATA PREPROCESSING

# %% [markdown]
# Outliers Handling

# %%
for i in train.columns:
    plt.figure()
    plt.boxplot(train[i])
    plt.title(i)

# %% [markdown]
# Inference: The columns Pixel resolution height have Outliers

# %%
for i in['px_height']:
    q1=np.percentile(train[i],25,interpolation='midpoint')
    q2=np.percentile(train[i],50,interpolation='midpoint')
    q3=np.percentile(train[i],75,interpolation='midpoint')
    iqr=q3-q1
    min_limit=q1-1.5*iqr
    max_limit=q3+1.5*iqr
    outlier=[]
    for x in train[i]:
        if((x>max_limit) or (x<min_limit)):
            outlier.append(x)
    print(outlier)
    train.loc[train[i]>max_limit,i]=np.median(train[i])
    train.loc[train[i]<min_limit,i]=np.median(train[i])
    print("Outliers in ",i," column is replaced")
# Out:
# [1949, 1960]
# Outliers in  px_height  column is replaced

# %% [markdown]
# Outlier in px_height has been replaced by median.

# %% [markdown]
# SCALING

# %%
from  sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler ()

# %%
train.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1135
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
import pickle

# %%
train['battery_power']=scale.fit_transform(train[['battery_power']])
bp_pkl = open('bp.pkl','wb')
pickle.dump(scale,bp_pkl)
bp_pkl.close()

# %%
train['int_memory']=scale.fit_transform(train[['int_memory']])
im_pkl = open('im.pkl','wb')
pickle.dump(scale,im_pkl)
im_pkl.close()

# %%
train['mobile_wt']=scale.fit_transform(train[['mobile_wt']])
mw_pkl = open('mw.pkl','wb')
pickle.dump(scale,mw_pkl)
mw_pkl.close()

# %%
train['px_height']=scale.fit_transform(train[['px_height']])
ph_pkl = open('ph.pkl','wb')
pickle.dump(scale,ph_pkl)
ph_pkl.close()

# %%
train['px_width']=scale.fit_transform(train[['px_width']])
pw_pkl = open('pw.pkl','wb')
pickle.dump(scale,pw_pkl)
pw_pkl.close()

# %%
train['ram']=scale.fit_transform(train[['ram']])
ram_pkl = open('ram.pkl','wb')
pickle.dump(scale,ram_pkl)
ram_pkl.close()

# %%
# data_scale=['battery_power','int_memory', 'mobile_wt', 'px_height','px_width','ram']
# for i in data_scale:
# train[i]=scale.fit_transform(train[[i]])
# test[i]=scale.transform(test[[i]])

# %%
train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0          0.227789     0          2.2         0   1       0    0.080645
# 1          0.347361     1          0.5         1   0       1    0.822581
# 2          0.041416     1          0.5         1   2       1    0.629032
# 3          0.076152     1          2.5         0   0       0    0.129032
# 4          0.881764     1          1.2         0  13       1    0.677419
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995       0.195725     1          0.5         1   0       1    0.000000
# 1996       0.977956     1          2.6         1   0       0    0.596774
# 1997       0.941884     0          0.9         1   1       1    0.548387
# 1998       0.675351     0          0.9         0   4       1    0.709677
# 1999       0.006012     1          2.0         1   5       1    0.693548
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width       ram  sc_h  \
# ...

# %% [markdown]
# **Feature Reduction**

# %%
#from the inference in Multivariate analysis, we can remove some fetures
# Inference:

# RAM and Price range of the smartphone are highly positivly correlated with each other.
# Pixel of Front camera and Primary camera are positivly correlated with each other.
# Pixel resolution width and pixel resolution height are positivly correlated with eachother.
# Screen width and Screen height are also shows positive correlation.
# Also battery power and Price range shows some positive correlation.

# %% [markdown]
# RAM and Battery power were positivly correlated with price_range ,So we need to keep that
#
# From the other three points we can remove any one of the features in:
#
# 1.Pixel of Front camera and Primary camera
#
# 2.Pixel resolution width and pixel resolution height
#
# 3.Screen width and Screen height

# %% [markdown]
# While analysing Primary camera,Pixel resolution width and Screen width were highly correlated compared to the other.So, we remove fc,px_height,sc_w

# %%
train=train.drop(['fc','px_height','sc_w'],axis=1)
test=test.drop(['id','fc','px_height','sc_w'],axis=1)
train
# Out:
#       battery_power  blue  clock_speed  dual_sim  four_g  int_memory  m_dep  \
# 0          0.227789     0          2.2         0       0    0.080645    0.6
# 1          0.347361     1          0.5         1       1    0.822581    0.7
# 2          0.041416     1          0.5         1       1    0.629032    0.9
# 3          0.076152     1          2.5         0       0    0.129032    0.8
# 4          0.881764     1          1.2         0       1    0.677419    0.6
# ...             ...   ...          ...       ...     ...         ...    ...
# 1995       0.195725     1          0.5         1       1    0.000000    0.8
# 1996       0.977956     1          2.6         1       0    0.596774    0.2
# 1997       0.941884     0          0.9         1       1    0.548387    0.7
# 1998       0.675351     0          0.9         0       1    0.709677    0.1
# 1999       0.006012     1          2.0         1       1    0.693548    0.9
#
# ...

# %%
test
# Out:
#      battery_power  blue  clock_speed  dual_sim  four_g  int_memory  m_dep  \
# 0             1043     1          1.8         1       0           5    0.1
# 1              841     1          0.5         1       1          61    0.8
# 2             1807     1          2.8         0       0          27    0.9
# 3             1546     0          0.5         1       1          25    0.5
# 4             1434     0          1.4         0       1          49    0.5
# ..             ...   ...          ...       ...     ...         ...    ...
# 995           1700     1          1.9         0       1          54    0.5
# 996            609     0          1.8         1       0          13    0.9
# 997           1185     0          1.4         0       1           8    0.5
# 998           1533     1          0.5         1       0          50    0.4
# 999           1270     1          0.5         0       1          35    0.1
#
# ...

# %% [markdown]
# Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
X=train.drop(["price_range"],axis=1)
calc_vif(X)
# Out:
#         variables       VIF
# 0   battery_power  3.640458
# 1            blue  1.972910
# 2     clock_speed  4.120805
# 3        dual_sim  1.990648
# 4          four_g  3.191775
# 5      int_memory  3.558354
# 6           m_dep  3.805086
# 7       mobile_wt  3.649054
# 8         n_cores  4.510436
# 9              pc  3.520371
# 10       px_width  3.837608
# 11            ram  3.822622
# 12           sc_h  7.822377
# 13      talk_time  4.686735
# 14        three_g  6.065611
# 15   touch_screen  1.974600
# 16           wifi  2.000051

# %%
#We can see sc_h and three_g have high variance so we can remove that columns also

# %%
train=train.drop(['three_g','sc_h'],axis=1)
test=test.drop(['three_g','sc_h'],axis=1)
train
# Out:
#       battery_power  blue  clock_speed  dual_sim  four_g  int_memory  m_dep  \
# 0          0.227789     0          2.2         0       0    0.080645    0.6
# 1          0.347361     1          0.5         1       1    0.822581    0.7
# 2          0.041416     1          0.5         1       1    0.629032    0.9
# 3          0.076152     1          2.5         0       0    0.129032    0.8
# 4          0.881764     1          1.2         0       1    0.677419    0.6
# ...             ...   ...          ...       ...     ...         ...    ...
# 1995       0.195725     1          0.5         1       1    0.000000    0.8
# 1996       0.977956     1          2.6         1       0    0.596774    0.2
# 1997       0.941884     0          0.9         1       1    0.548387    0.7
# 1998       0.675351     0          0.9         0       1    0.709677    0.1
# 1999       0.006012     1          2.0         1       1    0.693548    0.9
#
# ...

# %% [markdown]
# Model Building

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import  AdaBoostClassifier

from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, learning_curve, train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
from sklearn.metrics import accuracy_score

# %%
X=train.drop(columns=["price_range"],axis=1)
X
# Out:
#       battery_power  blue  clock_speed  dual_sim  four_g  int_memory  m_dep  \
# 0          0.227789     0          2.2         0       0    0.080645    0.6
# 1          0.347361     1          0.5         1       1    0.822581    0.7
# 2          0.041416     1          0.5         1       1    0.629032    0.9
# 3          0.076152     1          2.5         0       0    0.129032    0.8
# 4          0.881764     1          1.2         0       1    0.677419    0.6
# ...             ...   ...          ...       ...     ...         ...    ...
# 1995       0.195725     1          0.5         1       1    0.000000    0.8
# 1996       0.977956     1          2.6         1       0    0.596774    0.2
# 1997       0.941884     0          0.9         1       1    0.548387    0.7
# 1998       0.675351     0          0.9         0       1    0.709677    0.1
# 1999       0.006012     1          2.0         1       1    0.693548    0.9
#
# ...

# %%
Y=train["price_range"]
Y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,random_state=2,test_size=0.2)
x_train
# Out:
#       battery_power  blue  clock_speed  dual_sim  four_g  int_memory  m_dep  \
# 333        0.816299     1          1.0         0       1    0.080645    0.6
# 721        0.205077     0          0.5         1       0    0.096774    0.1
# 1352       0.198397     1          0.5         1       0    0.000000    0.8
# 1680       0.885104     1          0.5         1       1    0.758065    0.6
# 156        0.090848     0          2.3         0       1    0.935484    0.8
# ...             ...   ...          ...       ...     ...         ...    ...
# 1558       0.179025     0          0.5         1       1    0.838710    0.2
# 1608       0.419506     1          0.8         1       1    0.306452    0.6
# 493        0.935872     0          2.8         1       0    0.774194    0.8
# 527        0.854375     1          0.5         0       0    0.403226    0.1
# 1192       0.353373     1          0.5         0       1    0.564516    0.7
#
# ...

# %%
from sklearn.model_selection import StratifiedKFold
skf=StratifiedKFold(n_splits=10)

# %%
models={
    "KNeighbours classifier": KNeighborsClassifier(30),
    "Decision Tree Classifier": DecisionTreeClassifier(),
    "Random Forest Classifier":RandomForestClassifier(),
    "AdaBoost Classifier":AdaBoostClassifier(),
    "XGB Classifier":XGBClassifier(),
    'GaussianNB':GaussianNB(),
    'SVM':SVC()

}

# %%
for name,model in models.items():
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    print(name +" trained")
    cv_val=cross_val_score(model,X,Y,cv=skf)
    print(np.mean(cv_val))
    print(confusion_matrix(y_test,y_pred))
# Out:
# KNeighbours classifier trained
# 0.26749999999999996
# [[37 13 26 22]
#  [34 31 29 15]
#  [29 20 27 18]
#  [18 24 32 25]]
# Decision Tree Classifier trained
# 0.8290000000000001
# [[88 10  0  0]
#  [16 85  8  0]
#  [ 0  8 71 15]
#  [ 0  0 14 85]]
# Random Forest Classifier trained
# 0.8505
# [[96  2  0  0]
#  [19 81  9  0]
#  [ 0 10 75  9]
#  [ 0  0  5 94]]
# AdaBoost Classifier trained
# 0.7265
# [[75 23  0  0]
#  [10 88 11  0]
#  [ 0 19 54 21]
#  [ 0  0 38 61]]
# XGB Classifier trained
# 0.8739999999999999
# [[94  4  0  0]
#  [14 89  6  0]
#  [ 0  7 81  6]
#  [ 0  0  8 91]]
# GaussianNB trained
# 0.7870000000000001
# [[93  5  0  0]
#  [23 73 13  0]
#  [ 0 15 68 11]
#  [ 0  0  7 92]]
# SVM trained
# 0.35750000000000004
# [[33 26 39  0]
#  [39 28 40  2]
#  [22 22 39 11]
#  [ 6 18 36 39]]

# %% [markdown]
# Hyperparameter Tuning for Random Forest

# %%
from sklearn.model_selection import RandomizedSearchCV
n_estimators=[100,150,200]
max_features=['auto','sqrt','log2']
min_samples_split=[2,5,10]
min_samples_leaf=[1,2,4,6,8]
random_grid={'n_estimators':n_estimators,
             'max_features':max_features,
             'min_samples_split':min_samples_split,
             'min_samples_leaf':min_samples_leaf,
             'criterion':['entropy','gini']}

# %%
rf=RandomForestClassifier()
rf_randomcv=RandomizedSearchCV(estimator=rf, param_distributions=random_grid, n_iter=100, cv=3, verbose=2,random_state=100 )
rf_randomcv.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END criterion=entropy, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=entropy, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END criterion=gini, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END criterion=gini, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=   0.4s
# [CV] END criterion=gini, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   0.5s
# ...

# %%
rf_randomcv.best_params_
# Out:
# {'n_estimators': 150,
#  'min_samples_split': 5,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'criterion': 'gini'}

# %%
y_pred=rf_randomcv.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8925

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[96,  2,  0,  0],
#        [17, 83,  9,  0],
#        [ 0,  7, 84,  3],
#        [ 0,  0,  5, 94]])

# %% [markdown]
# Grid Search for Random Forest

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'n_estimators':[180,200,220],
             'max_features':['auto'],
             'min_samples_split':[0.8,2,2.2],
             'min_samples_leaf':[0.8,2,2.2],
             'criterion':['gini']}
grid_search=GridSearchCV(estimator=rf,param_grid=param_grid,cv=5,n_jobs=-1,verbose=2)
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini'], 'max_features': ['auto'],
#                          'min_samples_leaf': [0.8, 2, 2.2],
#                          'min_samples_split': [0.8, 2, 2.2],
#                          'n_estimators': [180, 200, 220]},
#              verbose=2)

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(max_features='auto', min_samples_leaf=2,
#                        n_estimators=220)

# %%
y_pred=grid_search.best_estimator_.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8775

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[95,  3,  0,  0],
#        [16, 84,  9,  0],
#        [ 0,  7, 78,  9],
#        [ 0,  0,  5, 94]])

# %%
cr=classification_report(y_test,y_pred)
cr
cr_lines = cr.split('\n')
cr_lines
# Out:
# ['              precision    recall  f1-score   support',
#  '',
#  '           0       0.86      0.97      0.91        98',
#  '           1       0.89      0.77      0.83       109',
#  '           2       0.85      0.83      0.84        94',
#  '           3       0.91      0.95      0.93        99',
#  '',
#  '    accuracy                           0.88       400',
#  '   macro avg       0.88      0.88      0.88       400',
#  'weighted avg       0.88      0.88      0.88       400',
#  '']

# %% [markdown]
# Hyperparameter for XGB

# %%
random_grid={'booster':['gbtree'],
             'eta':[0.05,0.1,0.2,0.3],
             'max_depth':[4,6,8],
             'subsample':[0.5,0.7,0.9]}
xgb=XGBClassifier()
xgb_randomcv=RandomizedSearchCV(estimator=xgb, param_distributions=random_grid, n_iter=100, cv=3, verbose=2,random_state=100 )
xgb_randomcv.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV] END booster=gbtree, eta=0.05, max_depth=4, subsample=0.5; total time=   3.8s
# [CV] END booster=gbtree, eta=0.05, max_depth=4, subsample=0.5; total time=   0.5s
# [CV] END booster=gbtree, eta=0.05, max_depth=4, subsample=0.5; total time=   0.4s
# [CV] END booster=gbtree, eta=0.05, max_depth=4, subsample=0.7; total time=   0.5s
# [CV] END booster=gbtree, eta=0.05, max_depth=4, subsample=0.7; total time=   0.5s
# [CV] END booster=gbtree, eta=0.05, max_depth=4, subsample=0.7; total time=   0.5s
# [CV] END booster=gbtree, eta=0.05, max_depth=4, subsample=0.9; total time=   0.5s
# [CV] END booster=gbtree, eta=0.05, max_depth=4, subsample=0.9; total time=   0.5s
# [CV] END booster=gbtree, eta=0.05, max_depth=4, subsample=0.9; total time=   0.5s
# [CV] END booster=gbtree, eta=0.05, max_depth=6, subsample=0.5; total time=   0.6s
# [CV] END booster=gbtree, eta=0.05, max_depth=6, subsample=0.5; total time=   0.6s
# ...

# %%
xgb_randomcv.best_params_
# Out:
# {'subsample': 0.9, 'max_depth': 4, 'eta': 0.1, 'booster': 'gbtree'}

# %%
y_pred=xgb_randomcv.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8975

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[94,  4,  0,  0],
#        [14, 90,  5,  0],
#        [ 0,  6, 83,  5],
#        [ 0,  0,  7, 92]])

# %% [markdown]
# Grid Search for XGB

# %%
param_grid={'booster':['gbtree'],
             'eta':[0.8,0.1,0.12],
             'max_depth':[3.5,4,4.25],
             'subsample':[0.875,0.9,0.925]}
grid_search=GridSearchCV(estimator=xgb,param_grid=param_grid,cv=5,n_jobs=-1,verbose=2)
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
# ...

# %%
grid_search.best_estimator_
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.1, eval_metric=None,
#               feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_pred=grid_search.best_estimator_.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8975

# %%
cr=classification_report(y_test,y_pred)
cr
cr_lines = cr.split('\n')
cr_lines
# Out:
# ['              precision    recall  f1-score   support',
#  '',
#  '           0       0.87      0.96      0.91        98',
#  '           1       0.90      0.83      0.86       109',
#  '           2       0.87      0.88      0.88        94',
#  '           3       0.95      0.93      0.94        99',
#  '',
#  '    accuracy                           0.90       400',
#  '   macro avg       0.90      0.90      0.90       400',
#  'weighted avg       0.90      0.90      0.90       400',
#  '']

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[94,  4,  0,  0],
#        [14, 90,  5,  0],
#        [ 0,  6, 83,  5],
#        [ 0,  0,  7, 92]])

# %% [markdown]
# Conclusion: We get an accuracy score of 0.8975 in randomsearch Cv and GridSearch CV of XGBoost for params {'subsample': 0.9, 'max_depth': 4, 'eta': 0.1, 'booster': 'gbtree'}

# %% [markdown]
# XGB Classifier model for pickle

# %%
xgb_model=XGBClassifier(subsample=0.9, max_depth=4, eta=0.1, booster='gbtree')
xgb_model=xgb_model.fit(x_train,y_train)
y_pred=xgb_model.predict(x_test)
y_pred
# Out:
# array([0, 2, 0, 2, 3, 1, 3, 3, 1, 2, 1, 0, 2, 3, 1, 3, 2, 1, 1, 3, 0, 2,
#        0, 1, 3, 2, 2, 0, 0, 2, 0, 3, 0, 0, 1, 0, 3, 0, 3, 2, 1, 1, 3, 2,
#        2, 0, 3, 2, 0, 3, 1, 3, 3, 2, 3, 0, 1, 0, 1, 1, 1, 2, 1, 2, 0, 2,
#        0, 1, 0, 3, 1, 0, 0, 2, 0, 2, 2, 3, 2, 2, 3, 2, 2, 0, 0, 3, 2, 2,
#        0, 1, 1, 2, 0, 0, 1, 2, 0, 3, 2, 0, 1, 3, 1, 1, 2, 3, 3, 3, 2, 1,
#        3, 1, 1, 2, 3, 0, 1, 1, 1, 1, 0, 3, 3, 0, 2, 0, 3, 1, 0, 0, 1, 3,
#        2, 1, 0, 3, 3, 0, 2, 0, 1, 3, 3, 0, 3, 2, 1, 3, 0, 1, 2, 3, 1, 3,
#        0, 3, 0, 2, 0, 1, 1, 1, 3, 0, 0, 3, 2, 3, 1, 0, 2, 1, 0, 3, 0, 1,
#        0, 1, 3, 3, 2, 2, 1, 1, 1, 0, 0, 1, 2, 2, 1, 0, 1, 1, 3, 2, 0, 1,
#        3, 1, 0, 2, 3, 0, 3, 3, 1, 3, 2, 3, 3, 2, 0, 0, 2, 1, 0, 1, 3, 0,
#        0, 3, 0, 1, 1, 0, 1, 3, 2, 2, 3, 3, 3, 0, 3, 0, 1, 2, 1, 3, 2, 2,
#        2, 0, 2, 3, 0, 3, 1, 1, 1, 0, 1, 3, 2, 1, 0, 3, 3, 0, 0, 0, 3, 3,
#        0, 3, 1, 0, 1, 0, 2, 0, 2, 0, 0, 0, 2, 0, 2, 0, 3, 3, 0, 2, 2, 1,
# ...

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8975

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[94,  4,  0,  0],
#        [14, 90,  5,  0],
#        [ 0,  6, 83,  5],
#        [ 0,  0,  7, 92]])

# %%
cr=classification_report(y_test,y_pred)
cr
cr_lines = cr.split('\n')
cr_lines
# Out:
# ['              precision    recall  f1-score   support',
#  '',
#  '           0       0.87      0.96      0.91        98',
#  '           1       0.90      0.83      0.86       109',
#  '           2       0.87      0.88      0.88        94',
#  '           3       0.95      0.93      0.94        99',
#  '',
#  '    accuracy                           0.90       400',
#  '   macro avg       0.90      0.90      0.90       400',
#  'weighted avg       0.90      0.90      0.90       400',
#  '']

# %%
xgb_pkl = open('xgb.pkl','wb')
pickle.dump(xgb_model,xgb_pkl)
xgb_pkl.close()

# %%
# aa.transform([[68062]])[0,0]
# mod=pickle.load(open('LoanRF.pkl','rb'))
# legrade=pickle.load(open('le.pkl','rb'))
# leownership=pickle.load(open('le1.pkl','rb'))
# scl_col=pickle.load(open('Coll.pkl','rb'))
# scl_dur=pickle.load(open('Dur.pkl','rb'))
# scl_late=pickle.load(open('L_Fee.pkl','rb'))
# scl_rbal=pickle.load(open('RBal.pkl','rb'))

# mod.predict(np.array([legrade.transform(['A'])[0],leownership.transform(['MORTGAGE'])[0],scl_dur.transform([[71528]])[0,0],10,scl_rbal.transform([[1553]])[0,0],14,
#              scl_late.transform([[0]])[0,0],scl_col.transform([[430]])[0,0]]).reshape(1,-1))[0]
